# %% [markdown]
# #### Actividad 6.2
#
# Ivanna Maldonado Cervantes

# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('Tokyo.csv')  # cargamos el archivo
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22783 entries, 0 to 22782
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            22783 non-null  int64
#  1   listing_url                                   22783 non-null  object
#  2   scrape_id                                     22783 non-null  int64
#  3   last_scraped                                  22783 non-null  object
#  4   source                                        22783 non-null  object
#  5   name                                          22783 non-null  object
#  6   description                                   22422 non-null  object
#  7   neighborhood_overview                         13142 non-null  object
#  8   picture_url                                   22783 non-null  object
# ...

# %%
valores_nulos=data.isnull().sum() #buscamos valores nulos
valores_nulos
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3103
# Length: 79, dtype: int64

# %%
#aplicamos los metodos para elminar outliers
#back
data1 =data.fillna(method="bfill") 
data1
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14328\654186717.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 =data.fillna(method="bfill")
#                         id                                       listing_url  \
# 0                   197677               https://www.airbnb.com/rooms/197677
# 1                   905944               https://www.airbnb.com/rooms/905944
# 2                  1016831              https://www.airbnb.com/rooms/1016831
# 3                  1196177              https://www.airbnb.com/rooms/1196177
# 4                  1249571              https://www.airbnb.com/rooms/1249571
# ...                    ...                                               ...
# 22778  1380096861872988432  https://www.airbnb.com/rooms/1380096861872988432
# 22779  1380108173469178648  https://www.airbnb.com/rooms/1380108173469178648
# ...

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# source                                            0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                               179
# Length: 79, dtype: int64

# %%
cuantitativas= data1.iloc[ : , 1:23 ] #hacemos 2 df para procesar los out
cualitativas= data1.iloc[ : , [0] ]

# %%
fig = plt.figure(figsize =(15, 8)) #realizamos un diagrama de caja
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe

plt.figure(figsize=(15, 8))
y.plot(kind="box", vert=False)
plt.title("Valores Atípicos de mi base de datos 'albany'")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 #Realizamos diagrama de caja o bigote de cada columna del dataframe
#       3 plt.figure(figsize=(15, 8))
# ----> 4 y.plot(kind="box", vert=False)
#       5 plt.title("Valores Atípicos de mi base de datos 'albany'")
#       6 plt.show()
#
# NameError: name 'y' is not defined
